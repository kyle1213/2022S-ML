# %% [markdown]
# <a href="https://colab.research.google.com/github/kyle1213/2022S-ML/blob/main/challenge_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge :: Cartoon Character Classification

# %% [markdown]
# 만화 이미지를 보고 어떤 캐릭터인지를 분류하는 테스크입니다.
# 캐릭터 클래스는 총 10개 입니다.

# %% [markdown]
# ## Download Data
# 데이터 출처: https://www.kaggle.com/datasets/volkandl/cartoon-classification

# %% [markdown]
# 코랩에서 캐글 데이터셋을 바로 불러오기 위해서 kaggle.json 파일이 필요합니다.
# ```캐글 본인 계정 페이지``` -> ```Account``` -> ```API``` -> ```Create New API Token```
# 로 kaggle.json 파일을 다운로드 받을 수 있습니다.

# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.64.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (6.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2022.5.18.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
#      <input type="file" id="files-06118268-697f-4635-bcb0-8b0d9176e141" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-06118268-697f-4635-bcb0-8b0d9176e141">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"kyle1213","key":"1558cb8326658b301615acd17b3fec09"}'}

# %%
ls -1ha kaggle.json # kaggle.json 확인
# Out:
# kaggle.json

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# Permission Warning 방지
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d volkandl/cartoon-classification
# Out:
# Downloading cartoon-classification.zip to /content
# 100% 11.5G/11.5G [00:48<00:00, 215MB/s]
# 100% 11.5G/11.5G [00:48<00:00, 253MB/s]

# %%
# !ls # 데이터셋 다운로드 확인
# Out:
# cartoon-classification.zip  kaggle.json  sample_data

# %%
# !unzip cartoon-classification.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5099.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY51.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY510.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5100.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5101.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5102.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5103.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5104.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5105.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5106.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5107.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5108.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5109.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY511.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5110.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5111.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5112.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5113.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5114.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5115.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5116.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5117.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5118.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5119.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY512.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5120.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5121.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5122.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5123.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5124.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5125.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5126.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5127.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5128.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5129.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY513.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5130.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5131.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5132.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5133.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5134.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5135.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5136.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5137.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5138.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5139.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY514.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5140.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5141.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5142.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5143.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5144.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5145.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5146.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5147.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5148.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5149.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY515.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5150.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5151.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5152.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5153.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5154.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5155.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5156.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5157.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5158.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5159.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY516.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5160.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5161.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5162.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5163.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5164.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5165.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5166.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5167.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5168.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5169.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY517.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5170.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5171.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5172.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5173.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5174.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5175.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5176.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5177.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5178.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5179.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY518.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5180.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5181.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5182.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5183.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5184.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5185.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5186.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5187.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5188.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5189.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY519.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5190.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5191.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5192.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5193.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5194.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5195.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5196.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5197.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5198.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5199.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY52.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY520.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5200.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5201.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5202.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5203.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5204.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5205.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5206.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5207.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5208.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5209.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY521.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5210.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5211.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5212.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5213.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5214.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5215.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5216.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5217.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5218.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5219.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY522.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5220.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5221.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5222.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5223.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5224.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5225.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5226.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5227.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5228.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5229.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY523.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5230.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5231.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5232.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5233.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5234.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5235.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5236.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5237.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5238.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5239.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY524.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5240.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5241.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5242.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5243.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5244.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5245.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5246.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5247.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5248.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5249.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY525.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5250.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5251.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5252.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5253.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5254.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5255.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5256.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5257.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5258.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5259.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY526.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5260.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5261.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5262.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5263.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5264.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5265.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5266.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5267.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5268.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5269.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY527.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5270.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5271.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5272.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5273.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5274.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5275.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5276.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5277.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5278.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5279.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY528.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5280.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5281.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5282.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5283.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5284.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5285.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5286.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5287.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5288.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5289.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY529.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5290.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY5291.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY
jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9426.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9427.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9428.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9429.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY943.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9430.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9431.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9432.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9433.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9434.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9435.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9436.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9437.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9438.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9439.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY944.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9440.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9441.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9442.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9443.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9444.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9445.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9446.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9447.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9448.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9449.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY945.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9450.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9451.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9452.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9453.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9454.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9455.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9456.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9457.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9458.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9459.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY946.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9460.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9461.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9462.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9463.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9464.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9465.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9466.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9467.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9468.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9469.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY947.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9470.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9471.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9472.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9473.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9474.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9475.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9476.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9477.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9478.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9479.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY948.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9480.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9481.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9482.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9483.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9484.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9485.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9486.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9487.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9488.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9489.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY949.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9490.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9491.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9492.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9493.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9494.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9495.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9496.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9497.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9498.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9499.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY95.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY950.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9500.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9501.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9502.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9503.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9504.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9505.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9506.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9507.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9508.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9509.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY951.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9510.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9511.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9512.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9513.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9514.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9515.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9516.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9517.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9518.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9519.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY952.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9520.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9521.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9522.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9523.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9524.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9525.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9526.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9527.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9528.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9529.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY953.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9530.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9531.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9532.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9533.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9534.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9535.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9536.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9537.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9538.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9539.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY954.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9540.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9541.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9542.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9543.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9544.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9545.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9546.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9547.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9548.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9549.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY955.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9550.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9551.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9552.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9553.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9554.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY9555.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY956.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY957.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY958.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY959.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY96.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY960.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY961.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY962.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY963.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY964.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY965.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY966.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY967.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY968.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY969.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY97.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY970.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY971.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY972.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY973.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY974.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY975.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY976.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY977.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY978.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY979.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY98.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY980.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY981.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY982.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY983.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY984.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY985.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY986.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY987.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY988.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY989.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY99.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY990.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY991.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY992.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY993.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY994.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY995.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY996.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY997.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY998.jpg
#   inflating: cartoon_classification/TRAIN/tom_and_jerry/TOM_AND_JERRY999.jpg

# %% [markdown]
# ## Load Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import torch
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import transforms, utils, datasets
import torch.utils.data
from time import time

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True # prevent truncate error

# %%
from torchvision.transforms.transforms import RandomHorizontalFlip
#tensor([0.4439, 0.4562, 0.4138]) tensor([0.2447, 0.2399, 0.2453])  train
image_transforms = {
    "train": transforms.Compose([
        transforms.Resize((600, 600)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.4439, 0.4562, 0.4138], [0.2447, 0.2399, 0.2453])
        
    ]),
    "test": transforms.Compose([
        transforms.Resize((600, 600)),
        transforms.ToTensor(),
        transforms.Normalize([0.4216, 0.4101, 0.3721], [0.2521, 0.2454, 0.2426]),
    ])
}#[0.4216, 0.4101, 0.3721]) tensor([0.2521, 0.2454, 0.2426] test

# %%
# From https://gist.github.com/andrewjong/6b02ff237533b3b2c554701fb53d5c4d

class ImageFolderWithPaths(datasets.ImageFolder):
    """Custom dataset that includes image file paths. Extends
    torchvision.datasets.ImageFolder
    """

    # override the __getitem__ method. this is the method that dataloader calls
    def __getitem__(self, index):
        # this is what ImageFolder normally returns 
        original_tuple = super(ImageFolderWithPaths, self).__getitem__(index)
        # the image file path
        path = self.imgs[index][0]
        # make a new tuple that includes original and the path
        tuple_with_path = (original_tuple + (path,))
        return tuple_with_path

# %%
train_data = ImageFolderWithPaths(root = './cartoon_classification/' + "TRAIN", # load train data      ######배치사이즈바꾸기
                                   transform = image_transforms["train"], 
                                  )
train_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True) # make train loader

# %%
test_data = ImageFolderWithPaths(root = './cartoon_classification/' + "TEST",
                                   transform = image_transforms["test"] # load test data
                                  )
test_loader = torch.utils.data.DataLoader(test_data, batch_size=1, shuffle=False ) # make test loader 
# shuffle false 로 하지 않으면 서버에서 테스트 할 때 문제 생김

# %%
N_CHANNELS = 3
"""
before = time()
mean = torch.zeros(3)
std = torch.zeros(3)
print(mean)
print('==> Computing mean and std..')

for inputs, _labels, _ in tqdm(train_loader):
    for i in range(N_CHANNELS):
      mean[i] += inputs[:,i,:,:].mean()
      std[i] += inputs[:,i,:,:].std()
mean.div_(len(train_data))
std.div_(len(train_data))
print(mean, std)

print("time elapsed: ", time()-before)



##################
before = time()
mean = torch.zeros(3)
std = torch.zeros(3)
print('==> Computing mean and std..')
for inputs, _labels, _ in tqdm(test_loader):
    for i in range(N_CHANNELS):
        mean[i] += inputs[:,i,:,:].mean()
        std[i] += inputs[:,i,:,:].std()
mean.div_(len(test_data))
std.div_(len(test_data))
print(mean, std)

print("time elapsed: ", time()-before)
"""
# Out:
# '\nbefore = time()\nmean = torch.zeros(3)\nstd = torch.zeros(3)\nprint(mean)\nprint(\'==> Computing mean and std..\')\n\nfor inputs, _labels, _ in tqdm(train_loader):\n    for i in range(N_CHANNELS):\n      mean[i] += inputs[:,i,:,:].mean()\n      std[i] += inputs[:,i,:,:].std()\nmean.div_(len(train_data))\nstd.div_(len(train_data))\nprint(mean, std)\n\nprint("time elapsed: ", time()-before)\n\n\n\n##################\nbefore = time()\nmean = torch.zeros(3)\nstd = torch.zeros(3)\nprint(\'==> Computing mean and std..\')\nfor inputs, _labels, _ in tqdm(test_loader):\n    for i in range(N_CHANNELS):\n        mean[i] += inputs[:,i,:,:].mean()\n        std[i] += inputs[:,i,:,:].std()\nmean.div_(len(test_data))\nstd.div_(len(test_data))\nprint(mean, std)\n\nprint("time elapsed: ", time()-before)\n'

# %%
classes = train_data.class_to_idx # class name
classes
# Out:
# {'Familyguy': 0,
#  'Gumball': 1,
#  'Tsubasa': 2,
#  'adventure_time': 3,
#  'catdog': 4,
#  'pokemon': 5,
#  'smurfs': 6,
#  'southpark': 7,
#  'spongebob': 8,
#  'tom_and_jerry': 9}

# %% [markdown]
# ## Show Example Data

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image


def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels, paths = dataiter.next()

batch_size = 16

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print()
labels = labels.tolist()
print(' '.join(f'{list(classes.keys())[list(classes.values()).index(j)]}' for j in labels))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# catdog pokemon catdog southpark pokemon pokemon spongebob Familyguy Tsubasa pokemon Gumball catdog adventure_time southpark Familyguy Familyguy adventure_time adventure_time Familyguy tom_and_jerry Gumball Tsubasa spongebob Gumball southpark pokemon Familyguy Gumball adventure_time Familyguy adventure_time Tsubasa

# %% [markdown]
# ## Define a Convolutional Neural Network

# %% [markdown]
# Modified https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1_layer = nn.Sequential(nn.Conv2d(3, 32, 3),
                                         nn.ReLU()) # in_channel, out_channel, kernel size
        self.conv2_layer = nn.Sequential(nn.Conv2d(32, 32, 3),
                                         nn.ReLU()) # in_channel, out_channel, kernel size
        self.conv3_layer = nn.Sequential(nn.Conv2d(32, 64, 3),
                                         nn.ReLU()) # in_channel, out_channel, kernel size                                
        self.conv4_layer = nn.Sequential(nn.Conv2d(64, 64, 3),
                                         nn.ReLU()) # in_channel, out_channel, kernel size

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.3)

        self.fc1 = nn.Linear(78400, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 10)

    def forward(self, x):
        x = self.pool(self.conv1_layer(x))
        x = self.pool(self.conv2_layer(x))
        x = self.pool(self.conv3_layer(x))
        x = self.pool(self.conv4_layer(x))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = self.dropout(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Use GPU if it's available

# %%
net = Net() # define the network
net = net.to(device) # send the network to the device
#PATH = './91.pth'
#net.load_state_dict(torch.load(PATH))

# %% [markdown]
# ## Define a Loss function and optimizer

# %%
from torchsummary import summary
criterion = nn.CrossEntropyLoss() # loss function
optimizer = optim.Adam(net.parameters(), weight_decay=5e-4) # optimizer
summary(net,(3,600,600),batch_size=1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [1, 32, 598, 598]             896
#               ReLU-2          [1, 32, 598, 598]               0
#          MaxPool2d-3          [1, 32, 299, 299]               0
#             Conv2d-4          [1, 32, 297, 297]           9,248
#               ReLU-5          [1, 32, 297, 297]               0
#          MaxPool2d-6          [1, 32, 148, 148]               0
#             Conv2d-7          [1, 64, 146, 146]          18,496
#               ReLU-8          [1, 64, 146, 146]               0
#          MaxPool2d-9            [1, 64, 73, 73]               0
#            Conv2d-10            [1, 64, 71, 71]          36,928
#              ReLU-11            [1, 64, 71, 71]               0
#         MaxPool2d-12            [1, 64, 35, 35]               0
#           Dropout-13                 [1, 78400]               0
#            Linear-14                  [1, 1024]      80,282,624
#           Dropout-15                  [1, 1024]               0
#            Linear-16                   [1, 512]         524,800
#           Dropout-17                   [1, 512]               0
#            Linear-18                    [1, 10]           5,130
# ================================================================
# Total params: 80,878,122
# Trainable params: 80,878,122
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 4.12
# Forward/backward pass size (MB): 274.42
# Params size (MB): 308.53
# Estimated Total Size (MB): 587.06
# ----------------------------------------------------------------

# %% [markdown]
# ## Train the Network

# %%
for epoch in range(20):  # loop over the dataset multiple times
    net.train()
    running_loss = 0.0
    for i, data in enumerate(tqdm(train_loader, 0)):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels, paths = data
        inputs = inputs.to(device)
        labels = labels.to(device)
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 600 == 599:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 600:.3f}')
            running_loss = 0.0
    

    net.eval()
    correct = 0
    total = 0
# since we're not training, we don't need to calculate the gradients for our outputs

    image_id = []
    predicted_label = []
    with torch.no_grad():
        for i, data in enumerate(tqdm(test_loader,0)):
            images, labels, paths = data
            images = images.to(device)
            labels = labels.to(device)
        # calculate outputs by running images through the network
            outputs = net(images)
        # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs.data, 1)
        
            image_id.append(paths)
            predicted_label.append(predicted.item())

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f'Accuracy of the network on the {len(test_loader.dataset)} test images: {100 * correct // total} %')

    PATH = './' + str(epoch) + '.pth'
    torch.save(net.state_dict(), PATH)

print('Finished Training') # colab pro+ 기준, 한 epoch 당 35분 소요
# Out:
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [1,   600] loss: 0.622
# [1,  1200] loss: 0.179
# [1,  1800] loss: 0.127
# [1,  2400] loss: 0.096
# [1,  3000] loss: 0.097
# [1,  3600] loss: 0.089
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 67 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [2,   600] loss: 0.076
# [2,  1200] loss: 0.075
# [2,  1800] loss: 0.058
# [2,  2400] loss: 0.064
# [2,  3000] loss: 0.072
# [2,  3600] loss: 0.052
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 66 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [3,   600] loss: 0.068
# [3,  1200] loss: 0.065
# [3,  1800] loss: 0.059
# [3,  2400] loss: 0.054
# [3,  3000] loss: 0.063
# [3,  3600] loss: 0.063
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 72 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [4,   600] loss: 0.057
# [4,  1200] loss: 0.046
# [4,  1800] loss: 0.063
# [4,  2400] loss: 0.052
# [4,  3000] loss: 0.048
# [4,  3600] loss: 0.055
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 72 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [5,   600] loss: 0.037
# [5,  1200] loss: 0.055
# [5,  1800] loss: 0.047
# [5,  2400] loss: 0.049
# [5,  3000] loss: 0.047
# [5,  3600] loss: 0.044
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 73 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [6,   600] loss: 0.046
# [6,  1200] loss: 0.052
# [6,  1800] loss: 0.032
# [6,  2400] loss: 0.047
# [6,  3000] loss: 0.050
# [6,  3600] loss: 0.039
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 66 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [7,   600] loss: 0.034
# [7,  1200] loss: 0.039
# [7,  1800] loss: 0.045
# [7,  2400] loss: 0.055
# [7,  3000] loss: 0.048
# [7,  3600] loss: 0.038
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 76 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [8,   600] loss: 0.039
# [8,  1200] loss: 0.038
# [8,  1800] loss: 0.039
# [8,  2400] loss: 0.029
# [8,  3000] loss: 0.045
# [8,  3600] loss: 0.054
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 76 %
# [18,  1200] loss: 0.035
# [18,  1800] loss: 0.032
# [18,  2400] loss: 0.033
# [18,  3000] loss: 0.033
# [18,  3600] loss: 0.030
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 81 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [19,   600] loss: 0.025
# [19,  1200] loss: 0.038
# [19,  1800] loss: 0.025
# [19,  2400] loss: 0.036
# [19,  3000] loss: 0.040
# [19,  3600] loss: 0.033
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 87 %
#   0%|          | 0/3739 [00:00<?, ?it/s]
# [20,   600] loss: 0.027
# [20,  1200] loss: 0.039
# [20,  1800] loss: 0.023
# [20,  2400] loss: 0.035
# [20,  3000] loss: 0.025
# [20,  3600] loss: 0.037
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 79 %
# Finished Training

# %% [markdown]
# ## Save the Network

# %%
# save the trained model
PATH = './19.pth'
#torch.save(net.state_dict(), PATH)

# %% [markdown]
# ## Load the Network

# %%
net = Net()
net = net.to(device)
net.load_state_dict(torch.load(PATH))
net = net.eval()

# %% [markdown]
# ## Testing & Making a Submission File

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs

image_id = []
predicted_label = []
with torch.no_grad():
    for i, data in enumerate(tqdm(test_loader,0)):
        images, labels, paths = data
        images = images.to(device)
        labels = labels.to(device)
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        
        image_id.append(paths)
        predicted_label.append(predicted.item())

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the {len(test_loader.dataset)} test images: {100 * correct // total} %')
# Out:
#   0%|          | 0/18110 [00:00<?, ?it/s]
# Accuracy of the network on the 18110 test images: 77 %

# %%
submit_sol = pd.DataFrame(list(zip(image_id, predicted_label)), columns=['id','predicted'])

# %%
submit_sol
# Out:
#                                                       id  predicted
# 0      (./cartoon_classification/TEST/Familyguy/famil...          0
# 1      (./cartoon_classification/TEST/Familyguy/famil...          0
# 2      (./cartoon_classification/TEST/Familyguy/famil...          0
# 3      (./cartoon_classification/TEST/Familyguy/famil...          0
# 4      (./cartoon_classification/TEST/Familyguy/famil...          0
# ...                                                  ...        ...
# 18105  (./cartoon_classification/TEST/tom_and_jerry/T...          9
# 18106  (./cartoon_classification/TEST/tom_and_jerry/T...          9
# 18107  (./cartoon_classification/TEST/tom_and_jerry/T...          9
# 18108  (./cartoon_classification/TEST/tom_and_jerry/T...          9
# 18109  (./cartoon_classification/TEST/tom_and_jerry/T...          9
#
# [18110 rows x 2 columns]

# %%
import os

def clean_path(path):
  cleaned_path = os.path.normpath(path)
  cleaned_path = path.split(os.sep)
  new_path = cleaned_path[3] +'/' + cleaned_path[4] # cartoon name/xx.jpg
  return new_path

# %%
path_list = []
for i in range(len(submit_sol)):
  out = clean_path(submit_sol.iloc[i][0][0])
  path_list.append(out)

submit_sol['id'] = path_list

# %%
submit_sol.to_csv('test_result.csv', index=False)  # submit this test_result.csv to kaggle server
